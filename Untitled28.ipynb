# %% [markdown]
#                                #GoogleAds Sale DataAnalytics

# %%
##Project Obecetives:

             The objective of this project to analyze the Google Ads Sale Dataset using python and perform exploratory data analysis(EDA).This project
aims to explore different advertising performance indicators such as clicks,impressions,cost,leads,conversions,conversion rate,and sale amount across
dofferent campaigns,keywords,locations,and devices.
Throuh exploratory data analysis(EDA),the project will identify patterns,trends,and relationship in digital marketing performance data.Data cleaning
will be performed to handle missing values,correct inconsistent column names,and remove duplicate records to ensure data quality.

# %% [markdown]
# #Data Loading and Initial Overview

# %% [markdown]
# ##Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv(r"C:\Users\MINU MUJSINA\Downloads\googleAds_sales_data.csv")

# %%
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       $1892  16-11-2024  hyderabad  desktop
# 1          8.0            0.046       $1679  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       $1624  16-11-2024  hyderabad  Desktop
# 3          6.0              NaN       $1225  26-11-2024  HYDERABAD   tablet
# 4          8.0              NaN       $1091  22-11-2024  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# ...

# %%
df.tail()
# Out:
#       Ad_ID         Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 2595  A3595   DataAnalyticsCourse    88.0       5344.0  $242.07   17.0
# 2596  A3596   DataAnalyticsCourse   154.0       3211.0  $248.28   14.0
# 2597  A3597   Data Anlytics Corse   113.0       3808.0  $233.25   18.0
# 2598  A3598  Data Analytics Corse   196.0       5853.0  $220.13   16.0
# 2599  A3599  Data Analytics Corse     NaN       5453.0      NaN   12.0
#
#       Conversions  Conversion Rate Sale_Amount     Ad_Date   Location  \
# 2595          9.0            0.054       $1418  29-11-2024  HYDERABAD
# 2596          6.0            0.039       $1950  28-11-2024  hyderabad
# 2597          4.0            0.035       $1085  02-11-2024   Hyderbad
# 2598          7.0            0.036       $1558  08-11-2024   hydrebad
# 2599          5.0              NaN       $1174  22-11-2024  HYDERABAD
#
#        Device                 Keyword
# 2595   MOBILE    online data analytic
# 2596   TABLET   data analitics online
# ...

# %%
df.shape
# Out:
# (2600, 13)

# %% [markdown]
# ##Column Description

# %%
1.Ad_ID                                         - Unique ID of advertisement
2.Campaign_Name                                  - Name of marketing campaign
3.Clicks                                         -Number of users clicked
4.Impressions                                     - Number of times ad shown
5.Cost                                             -Money spent on ads
6.Leads                                            -Interested users
7.Conversions                                       -Final actions
8.Conversion Rate                                   -percentage of success
9.Sale_amount                                       -Revenue generated
10.Ad_Date                                            -Date of ad
11.Location                                          -Users location
12.Device                                             -Mobile/Desktop/Tablet
13.keyword                                            -search keyword

# %%
df.columns
# Out:
# Index(['Ad_ID', 'Campaign_Name', 'Clicks', 'Impressions', 'Cost', 'Leads',
#        'Conversions', 'Conversion Rate', 'Sale_Amount', 'Ad_Date', 'Location',
#        'Device', 'Keyword'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Clicks  Impressions        Leads  Conversions  Conversion Rate
# count  2488.000000  2546.000000  2552.000000  2526.000000      1974.000000
# mean    138.956994  4523.280833    20.003918     6.519002         0.048979
# std      34.619376   869.927913     6.032317     2.272573         0.019987
# min      80.000000  3000.000000    10.000000     3.000000         0.015000
# 25%     110.000000  3764.000000    15.000000     5.000000         0.035000
# 50%     139.000000  4518.500000    20.000000     7.000000         0.046000
# 75%     169.000000  5279.500000    25.000000     9.000000         0.058000
# max     199.000000  5999.000000    30.000000    10.000000         0.123000

# %% [markdown]
# ##Data Pre-Proceeing

# %%
df.isnull().sum()
# Out:
# Ad_ID                0
# Campaign_Name        0
# Clicks             112
# Impressions         54
# Cost                97
# Leads               48
# Conversions         74
# Conversion Rate    626
# Sale_Amount        139
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64
